# %%
import os

# %%
import sys

# %%
from pathlib import Path

# %%
PACKAGE_PATH = Path(os.getcwd()).parent

# %%
sys.path.append(str(PACKAGE_PATH))

# %%
import numpy as np

# %%
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# ## 1. Load the Data
